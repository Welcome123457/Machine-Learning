# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\PAVAN G\Downloads\insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
x=df['age']
y=df['bought_insurance']

# %%
plt.scatter(x,y,marker="+",color='green')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['age']],df.bought_insurance,test_size=0.1,random_state=20)

# %%
x_train
# Out:
#     age
# 10   18
# 26   23
# 12   27
# 18   19
# 25   54
# 23   45
# 22   40
# 21   26
# 5    56
# 24   50
# 19   18
# 14   49
# 17   58
# 6    55
# 16   25
# 8    62
# 0    22
# 2    47
# 7    60
# 11   28
# 20   21
# 9    61
# 15   55
# 3    52

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    1
# 25    1
# 26    0
# Name: bought_insurance, dtype: int64

# %%
y_train
# Out:
# 10    0
# 26    0
# 12    0
# 18    0
# 25    1
# 23    1
# 22    1
# 21    0
# 5     1
# 24    1
# 19    0
# 14    1
# 17    1
# 6     0
# 16    1
# 8     1
# 0     0
# 2     1
# 7     1
# 11    0
# 20    0
# 9     1
# 15    1
# 3     0
# Name: bought_insurance, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression ()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array([0, 1, 0], dtype=int64)

# %%
y_test
# Out:
# 13    0
# 4     1
# 1     0
# Name: bought_insurance, dtype: int64

# %%
lr.score(x_test,y_test)
# Out:
# 1.0

# %%
lr.predict_proba(x_test)
# Out:
# array([[0.76521326, 0.23478674],
#        [0.28378442, 0.71621558],
#        [0.84254653, 0.15745347]])

# %%
lr.predict(x_test)
# Out:
# array([0, 1, 0], dtype=int64)

# %%
y_test
# Out:
# 13    0
# 4     1
# 1     0
# Name: bought_insurance, dtype: int64

# %%
lr.predict(x_test)
# Out:
# array([0, 1, 0], dtype=int64)

# %%
x_test
# Out:
#     age
# 13   29
# 4    46
# 1    25

# %%
lr.coef_
# Out:
# array([[0.12395549]])

# %%
lr.intercept_
# Out:
# array([-4.77618606])
